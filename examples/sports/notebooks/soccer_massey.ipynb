# %% [markdown]
# # Massey Example

# %%
from apprate.datasets.filenames import dataset_path, FILENAME_EPL_2018_2019_20_GAMES
from apprate.ratings.massey import Massey
filename = dataset_path(FILENAME_EPL_2018_2019_20_GAMES)
Massey().rate_from_file(filename)
# Out:
#               Item  rating  ranking
# 0          Arsenal -57.250       19
# 1      Bournemouth  -8.500       11
# 2         Brighton  38.375        2
# 3          Burnley  37.125        5
# 4          Cardiff -10.250       15
# 5          Chelsea -56.500       18
# 6   Crystal Palace  -8.250       10
# 7          Everton  36.875        6
# 8           Fulham -10.500       16
# 9     Huddersfield -59.750       20
# 10       Leicester  37.625        4
# 11       Liverpool  -6.000        9
# 12        Man City -55.000       17
# 13      Man United  38.000        3
# 14       Newcastle -10.000       14
# 15     Southampton  36.500        7
# 16       Tottenham  -8.750       12
# 17         Watford  39.750        1
# 18        West Ham  -9.750       13
# 19          Wolves  36.250        8
